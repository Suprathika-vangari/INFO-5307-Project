# %% [markdown]
# <a href="https://colab.research.google.com/github/Suprathika-vangari/INFO-5307-Project/blob/main/INFO_5307_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1:**
# * Using Pandas for data manipulation and Plotly Express for visualization, both
# crucial tools for data analysis in Python.
# * This will enable us to handle the dataset and create insightful visualizations to tackle Walmart's inventory management issues.

# %%
import pandas as pd
from datetime import datetime
import plotly.express as px
import pandas as pd

# %% [markdown]
# **Step 2:**
# * Reading a CSV file named 'walmart.csv' using Pandas and then reducing the dataset to the first 50,000 rows before saving it as 'walmart_trim.csv'.
# * Trimming the dataset might be a practical approach to start analyzing a smaller subset for faster processing or to focus on specific portions of the data. This step helped streamline the exploratory analysis by working with a manageable subset.

# %%
data = pd.read_csv('walmart.csv',encoding= 'latin-1')
data = data[:50000]
data.to_csv('walmart_trim.csv',index= False)
# Out:
# <ipython-input-38-88aeeb798a28>:1: DtypeWarning:
#
# Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
#printing columns/features from the dataset
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Store', 'Date', 'IsHoliday', 'Dept', 'Weekly_Sales',
#        'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3',
#        'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment', 'Type', 'Size',
#        'product_container', 'product_name', 'product_sub_category', 'profit',
#        'region', 'sales', 'ship_date', 'ship_mode', 'shipping_cost', 'state',
#        'unit_price', 'zip_code', 'day_of_week', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# **Step 3:**
# * Mapping the numerical store IDs to their corresponding store names, converting the 'Date' column to a datetime format, and then deriving additional features like 'day_of_week', 'month', and 'year' from the date.
# * This transformation is quite helpful as it allows for better analysis based on specific time-related trends such as sales patterns across different days, months, and years. Understanding the temporal aspects of sales data is crucial for inventory management, especially in recognizing seasonal variations and periodic trends.

# %%
store_mapping = {1: 'Store_1', 2: 'Store_2', 3: 'Store_3',4:'Store_4',5:'Store_5',6:'Store_6',None: 'Null'}  # Add more mappings as needed
data['Store'] = data['Store'].map(store_mapping)
data['Date'] = pd.to_datetime(data['Date'])
data['day_of_week'] = data['Date'].dt.strftime('%A')
data['month'] = data['Date'].dt.month_name()
data['year'] = data['Date'].dt.year

# %% [markdown]
# **Step 4:**
# * Performed some significant data cleaning steps.
# * Tried to refine the dataset by filtering rows based on specific criteria, such as selecting the top modes of shipping, regions, and states that have higher occurrences.
# * Additionally,handled missing or erroneous values in the 'unit_price', 'sales', and 'Dept' columns by converting them to numeric types, dropping NaN values, and ensuring data consistency by converting 'sales' to float and 'Dept' to string type.
#
# * Cleaning the data is a crucial step in preparing it for analysis. By removing irrelevant or inconsistent entries and ensuring data integrity, you're setting the foundation for more accurate and reliable insights into Walmart's inventory management.

# %%
print('Data Before Cleaning: {}'.format(len(data)))
# Data Cleaning
clean_data = data[data['ship_mode'].isin(list(data['ship_mode'].value_counts().keys())[:3])]
clean_data = clean_data[clean_data['region'].isin(list(data['region'].value_counts().keys())[:4])]
clean_data = clean_data[clean_data['state'].isin(list(data['state'].value_counts().keys())[:50])] # considering top 40 states
numeric_column = pd.to_numeric(clean_data['unit_price'], errors='coerce')
clean_data = clean_data[numeric_column.notna()]
numeric_column2 = pd.to_numeric(clean_data['sales'], errors='coerce')
clean_data = clean_data[numeric_column2.notna()]
clean_data = clean_data[clean_data['Dept']!='nan']
clean_data.dropna(subset=['Dept'], inplace=True)
clean_data['sales'] = clean_data['sales'].astype(float)
clean_data['Dept'] = clean_data['Dept'].astype(str)
print('Data After Cleaning: {}'.format(len(clean_data)))
# Out:
# Data Before Cleaning: 50000
# Data After Cleaning: 48404

# %% [markdown]
# **Step 5:**
# * Selected specific columns relevant to inventory management and created a subset named 'inventory_data'. Truncating the 'product_name' column to the first 25 characters could facilitate easier analysis and visualization. Additionally, isolated data for the years 2011 and 2012 in the 'yearly_data' subset, possibly for analyzing trends or patterns over these years.
#
# * By narrowing down to essential columns and focusing on specific years, I'm aiming for more targeted insights into inventory-related trends and sales patterns during those periods. This refined dataset will likely streamline the subsequent exploratory analysis for inventory management solutions

# %%
inventory_related_columns = ['Date','Dept', 'Weekly_Sales', 'product_container', 'product_name', 'product_sub_category', 'sales', 'ship_date', 'ship_mode', 'unit_price','Store','day_of_week','month','year','state','region','zip_code','profit', 'MarkDown1']
inventory_data = clean_data[inventory_related_columns]
inventory_data['product_name'] = inventory_data['product_name'].str.slice(0, 25)
yearly_data = inventory_data[(inventory_data['year']==2012)|(inventory_data['year']==2011)] # for monthly usage purpose
inventory_data.head()
# Out:
# <ipython-input-81-4179f727b051>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Date  Dept  Weekly_Sales product_container               product_name  \
# 0 2010-02-05   1.0      24924.50        Jumbo Drum  Global Enterprise Series
# 1 2010-02-05  26.0      11737.12        Jumbo Drum  Global Enterprise Series
# 2 2010-02-05  17.0      13223.76         Jumbo Box  Bevis Rectangular Confere
# 3 2010-02-05  45.0         37.44         Small Box                 Xerox 1923
# 4 2010-02-05  28.0       1085.29         Small Box  SAFCO Mobile Desk Side Fi
#
#      product_sub_category    sales   ship_date       ship_mode unit_price  \
# 0      Chairs & Chairmats    21.84    3/2/2020  Delivery Truck       3.29
# 1      Chairs & Chairmats  1811.67    3/7/2020  Delivery Truck     258.98
# 2                  Tables  6129.06  11/15/2021  Delivery Truck     145.98
# 3                   Paper   198.90    8/8/2020     Regular Air       6.68
# 4  Storage & Organization  1875.28   8/18/2021     Express Air      42.76
#
#      Store day_of_week     month  year      state   region zip_code  \
# 0  Store_1      Friday  February  2010  Wisconsin  Central    54481
# 1  Store_1      Friday  February  2010  Wisconsin  Central    54481
# 2  Store_1      Friday  February  2010      Texas  Central    76051
# 3  Store_1      Friday  February  2010    Arizona     West    85281
# 4  Store_1      Friday  February  2010    Florida    South    33063
#
#         profit  MarkDown1
# 0  19559.92268        NaN
# 1  19559.92268        NaN
# 2    7535.9388        NaN
# 3  18860.92419        NaN
# 4   24750.4921        NaN

# %%
inventory_data.shape
# Out:
# (48404, 18)

# %%
product_counts = inventory_data['product_name'].value_counts().head(20)

fig = px.bar(product_counts, x=product_counts.index, y=product_counts.values,
labels={'x': 'Product Name', 'y': 'Count'},
title='Top 10 Products by Count')

fig.update_layout(xaxis_title_text='Product Name', yaxis_title_text='Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="155ec158-4739-4a69-ae34-388d2b13aef7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("155ec158-4739-4a69-ae34-388d2b13aef7")) {                    Plotly.newPlot(                        "155ec158-4739-4a69-ae34-388d2b13aef7",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Adams Telephone Message B","Executive Impressions 14 ","Iceberg OfficeWorks 42 Ro","Chromcraft Bull-Nose Wood","Bush Advantage Collection","Bevis Round Conference Ta","Kensington 7 Outlet Maste","Wirebound Message Books  ","Honeywell Enviracaire Por","Holmes Replacement Filter","Global Enterprise Series ","Master Caster Door Stop  ","Acco Pressboard Covers wi","Westinghouse Floor Lamp w","Tenex B1-RE Series Chair ","Eldon ClusterMat Chair Ma","Chromcraft 48 x 96 Racetr","Tensor Computer Mounted L","Staples #10 Laser & Inkje","Bush Mission Pointe Libra"],"xaxis":"x","y":[159,148,144,135,133,126,126,122,120,114,113,111,102,98,94,92,92,91,90,90],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar ...

# %%
inventory_data['profit'] = inventory_data['profit'].astype(float)
category_profit_counts = inventory_data.groupby(['product_sub_category']).agg({'profit':'sum'}).reset_index()
px.line(category_profit_counts,x='product_sub_category',y='profit',markers=True,title= 'Sales vs Department Graph')
# Out:
# <ipython-input-74-cc0128b8b8da>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fae17954-4a22-48ff-bfe1-e4f7eee53ef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fae17954-4a22-48ff-bfe1-e4f7eee53ef5")) {                    Plotly.newPlot(                        "fae17954-4a22-48ff-bfe1-e4f7eee53ef5",                        [{"hovertemplate":"product_sub_category=%{x}\u003cbr\u003eprofit=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["Appliances","Binders and Binder Accessories","Bookcases","Chairs & Chairmats","Computer Peripherals","Copiers and Fax","Envelopes","Labels","Office Furnishings","Office Machines","Paper","Pens & Art Supplies","Rubber Bands","Storage & Organization","Tables","Telephones and Communication"],"xaxis":"x","y":[18132859.14316,31232009.152,8263623.24859,14171636.95191,26187903.3,3735577.1312700002,7731173.02835,10214207.16411,37126160.42403,13812880.34846,48359376.26297,25405385.13546,7717907.63475,22704157.94161,13276598.9075,30235427.4254],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"ty ...

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
yearly_data['month'] = pd.Categorical(yearly_data['month'], categories=month_order, ordered=True)
shipping_month_counts = yearly_data.groupby(['month','ship_mode']).agg({'sales':'count'}).reset_index()
shipping_month_counts.columns = ['month','ship_mode','count']
fig = px.scatter(shipping_month_counts, x="month", y="count", color="ship_mode",
                 size='count',title= 'Shipping Mode vs Month Analysis')
fig.show()
# Out:
# <ipython-input-61-6b07ad72d486>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17c614bf-29db-42fc-8e30-7fbbdab6355c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17c614bf-29db-42fc-8e30-7fbbdab6355c")) {                    Plotly.newPlot(                        "17c614bf-29db-42fc-8e30-7fbbdab6355c",                        [{"hovertemplate":"ship_mode=Delivery Truck\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delivery Truck","marker":{"color":"#636efa","size":[837,866,1016,971,855,942,971,998,1030,875,439,571],"sizemode":"area","sizeref":2.6275,"symbol":"circle"},"mode":"markers","name":"Delivery Truck","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[837,866,1016,971,855,942,971,998,1030,875,439,571],"yaxis":"y","type":"scatter"},{"hovertemplate":"ship_mode=Express Air\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Express Air","marker":{"color":"#EF553B","size":[920,890,1020,1051,905,979,969,985,994,892,432,568],"sizemode":"area","sizeref":2.6275,"symbol":"circle"},"mode":"markers","name":"Express Air","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[920,890,1020,1051,905,979,969,985,994,892,432,568],"yaxis":"y","type":"scatter"},{"hovertemplate":"ship_mode=Regular Air\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Regular Air","marker":{"color":"#00cc96","size":[899,918,962,972,889,1027,986,979,966,914,464,563],"sizemode":"area","sizeref":2.6275,"symbol":"circle"},"mode":"markers","name":"Regular Air","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[899,918,962,972,889,1027,986,979,966,914,464,563],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet" ...

# %%
store_counts = inventory_data.groupby(['Store','product_sub_category']).agg({'sales':'sum'}).reset_index()
store_counts.columns = ['Store','product_sub_category','sales']
fig = px.bar(store_counts, x="Store", y="sales", color="product_sub_category", title="Store-Category counts", barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a3cc5aaa-ebb7-41a7-9db5-b1e082fc4093" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3cc5aaa-ebb7-41a7-9db5-b1e082fc4093")) {                    Plotly.newPlot(                        "a3cc5aaa-ebb7-41a7-9db5-b1e082fc4093",                        [{"alignmentgroup":"True","hovertemplate":"product_sub_category=Appliances\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[1221695.97,1057655.7,1079068.92,1131683.3,833202.75,155216.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Binders and Binder Accessories\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders and Binder Accessories","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Binders and Binder Accessories","offsetgroup":"Binders and Binder Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[1525220.2,2012921.4,1419457.57,1799653.93,1244057.93,73937.83],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Bookcases\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[1211343.28,868642.4,845557.62,988297.58,1035269.89,117908.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Chairs & Chairmats\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chairs & Chairmats","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chairs & Chairmats","offsetgroup":"Chairs & Chairmats","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[1693818.43,2019594.36,1648884.61,1831888.71,1649264.07,173822.91],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Computer Peripherals\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Computer Peripherals","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Computer Peripherals","offsetgroup":"Computer Peripherals","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[887718.03,866463.38,748328.79,810425.69,739662.92,102412.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Copiers and Fax\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Copiers and Fax","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Copiers and Fax","offsetgroup":"Copiers and Fax","orientation":"v","showlegend":true,"textposition":"auto","x":["Store_1","Store_2","Store_3","Store_4","Store_5","Store_6"],"xaxis":"x","y":[1780302.1,2171304.29,2089583.32,1400010.71,1556465.46,107873.98000000001],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Envelopes\u003cbr\u003eStore=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u ...

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
yearly_data['month'] = pd.Categorical(yearly_data['month'], categories=month_order, ordered=True)
yearly_data['sales']= yearly_data['sales'].astype(float)
store_month_counts = yearly_data.groupby(['Store','month']).agg({'sales':'sum'}).reset_index()
store_month_counts.columns = ['Store','month','count']
fig = px.line(store_month_counts, x="month", y="count", color="Store",category_orders={'month': month_order},markers = True,title= 'Month-Store Analysis')
fig.update_traces(textposition="bottom right")
fig.show()
# Out:
# <ipython-input-33-8d72e8a6f79f>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-33-8d72e8a6f79f>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="24220c63-97e5-41da-8d73-d4d0d890f40d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24220c63-97e5-41da-8d73-d4d0d890f40d")) {                    Plotly.newPlot(                        "24220c63-97e5-41da-8d73-d4d0d890f40d",                        [{"hovertemplate":"Store=Store_1\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Store_1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Store_1","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1367108.15,1184955.71,1577306.83,1458013.22,1285897.86,1494607.19,1135442.64,1191670.06,1349020.0,1424085.45,757540.44,649250.23],"yaxis":"y","type":"scatter","textposition":"bottom right"},{"hovertemplate":"Store=Store_2\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Store_2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Store_2","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1261959.32,1077776.27,1772872.4,1452482.35,1198934.37,1357884.16,1166774.72,1764877.55,1520488.82,1319910.91,570756.96,913503.66],"yaxis":"y","type":"scatter","textposition":"bottom right"},{"hovertemplate":"Store=Store_3\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Store_3","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Store_3","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1163340.69,1400775.28,1408325.33,1283145.59,1351765.78,949438.9,1435426.89,1332690.63,1076074.37,957494.59,379465.32,800764.48],"yaxis":"y","type":"scatter","textposition":"bottom right"},{"hovertemplate":"Store=Store_4\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Store_4","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Store_4","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1162513.56,1275935.51,1836942.64,1471132.8,1093664.84,1386480.8,1442039.42,1404741.15,1386867.43,1195429.59,538532.83,663695.49],"yaxis":"y","type":"scatter","textposition":"bottom right"},{"hovertemplate":"Store=Store_5\u003cbr\u003emonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Store_5","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Store_5","orientation":"v","showlegend":true,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[1379037.78,929660.84,1009037.67,1432504.24,1266605.79,1587726.02,1229268.93,965299.6799999999,1455870.39,1092297.99,419788.88,787701.05],"yaxis":"y","type":"scatter","textposition":"bottom right"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0. ...

# %%
store_counts = inventory_data.groupby(['state','product_sub_category']).agg({'sales':'sum'}).reset_index()
store_counts.columns = ['state','product_sub_category','sales']
fig = px.bar(store_counts, x="state", y="sales", color="product_sub_category", title="State-Sub Catergory counts")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="248df12c-5532-42d1-9cb6-1664b855d205" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("248df12c-5532-42d1-9cb6-1664b855d205")) {                    Plotly.newPlot(                        "248df12c-5532-42d1-9cb6-1664b855d205",                        [{"alignmentgroup":"True","hovertemplate":"product_sub_category=Appliances\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnesota","Mississippi","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"xaxis":"x","y":[103967.4,79049.85,88631.48,449635.95,88022.32,109767.1,320643.56,66317.48,45155.91,267766.26,109954.19,76768.44,71468.86,32005.25,58185.770000000004,419451.48,97172.87,25350.11,67178.59,109765.09,148587.64,34894.630000000005,31117.85,26072.25,16085.45,10370.03,414235.85,23195.62,174109.63999999998,96972.73,25067.059999999998,236048.63999999998,79355.74,95225.67,150560.23,41214.71,71403.23,25302.42,153270.15,392149.02,66096.0,31852.16,148433.12,165589.06,14390.45,111104.67,9561.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Binders and Binder Accessories\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders and Binder Accessories","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Binders and Binder Accessories","offsetgroup":"Binders and Binder Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnesota","Mississippi","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"xaxis":"x","y":[49616.22,96409.48,67654.05,442445.56,148925.37,248566.86000000002,337501.43,150300.79,107789.05,399661.2,235179.03,92530.44,123775.32,9550.26,15474.289999999999,667004.02,138124.79,8403.85,247809.49,236129.84,360455.38,19529.93,8579.32,54056.99,35334.98,4661.74,352529.38,123797.86,302784.5,364501.26,22436.96,255835.92,108989.43,143116.78,486131.03,108131.19,104794.08,2315.55,157807.53,456578.27,248970.0,73001.67,129776.6,157427.74,31188.629999999997,126214.63,13450.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Bookcases\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnes ...

# %%
inventory_data['sales'] = inventory_data['sales'].astype(float)
inventory_data['Dept'] = inventory_data['Dept'].astype(str)
state_dept = inventory_data.groupby(['state','Dept']).agg({'sales':'sum'}).reset_index()
fig = px.scatter(state_dept, x="state", y="sales", color="Dept",title='State/Dept Sales')
fig.show()
# Out:
# <ipython-input-35-96e4e20f56ab>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-35-96e4e20f56ab>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a91e6dc-0ed1-4f6a-b267-8a5feeadc062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a91e6dc-0ed1-4f6a-b267-8a5feeadc062")) {                    Plotly.newPlot(                        "3a91e6dc-0ed1-4f6a-b267-8a5feeadc062",                        [{"hovertemplate":"Dept=1.0\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1.0","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"1.0","showlegend":true,"x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnesota","Mississippi","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"xaxis":"x","y":[36562.4,26433.61,2668.72,161027.68,8800.9,46065.4,81235.74,13898.09,13827.939999999999,92049.32,23761.37,10113.02,4923.780000000001,2056.47,7490.13,70902.1,23388.22,43575.090000000004,35129.88,22289.83,12500.880000000001,2088.2200000000003,1089.6,855.92,21942.2,9289.539999999999,31002.06,10754.1,50463.0,39178.11,1458.55,31857.469999999998,32031.5,16866.63,19792.77,7610.57,19782.88,4964.0599999999995,14236.159999999998,116743.25,26425.15,10195.220000000001,39788.06,16227.77,1243.08,15864.45,6185.35],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Dept=10.0\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"10.0","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"10.0","showlegend":true,"x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnesota","Mississippi","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"xaxis":"x","y":[10259.97,21795.85,19303.42,88947.89,8708.69,32090.34,51278.479999999996,23693.09,80577.14,232195.86,29701.89,6234.79,8852.95,556.28,18167.480000000003,79617.83,23077.25,19980.059999999998,25702.12,74557.71,22616.72,1184.7,1861.92,11903.630000000001,3800.1099999999997,9916.71,68918.15000000001,2546.68,48119.79,42108.33,4070.3599999999997,48807.89,60126.29,23629.079999999998,31273.959999999995,5922.18,15385.34,1853.46,30129.11,58081.02,3446.23,431.89,52691.68,101801.01,19592.829999999998,43434.6,160.29],"yaxis":"y","type":"scattergl"},{"hovertemplate":"Dept=11.0\u003cbr\u003estate=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"11.0","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"11.0","showlegend":true,"x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","MA","MO","Maine","Maryland","Michigan","Minnesota","Mississippi","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"xaxis":"x","y":[21562.04,17609. ...

# %%
inventory_data['Dept'] = inventory_data['Dept'].astype(str)
inventory_data['sales']= inventory_data['sales'].astype(float)
store_month_counts = inventory_data.groupby(['Dept']).agg({'sales':'sum'}).reset_index()
px.line(store_month_counts,x='Dept',y='sales',markers=True,title= 'Sales vs Department Graph')
# Out:
# <ipython-input-14-6c277d765d0c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-14-6c277d765d0c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bb0d377-fbdf-4195-92db-6d6051b5647c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bb0d377-fbdf-4195-92db-6d6051b5647c")) {                    Plotly.newPlot(                        "5bb0d377-fbdf-4195-92db-6d6051b5647c",                        [{"hovertemplate":"Dept=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1.0","10.0","11.0","12.0","13.0","14.0","16.0","17.0","18.0","19.0","2.0","20.0","21.0","22.0","23.0","24.0","25.0","26.0","27.0","28.0","29.0","3.0","30.0","31.0","32.0","33.0","34.0","35.0","36.0","37.0","38.0","39.0","4.0","40.0","41.0","42.0","44.0","45.0","46.0","47.0","48.0","49.0","5.0","51.0","52.0","54.0","55.0","56.0","58.0","59.0","6.0","60.0","67.0","7.0","71.0","72.0","74.0","77.0","78.0","79.0","8.0","80.0","81.0","82.0","83.0","85.0","87.0","9.0","90.0","91.0","92.0","93.0","94.0","95.0","96.0","97.0","98.0","99.0"],"xaxis":"x","y":[1286636.24,1569113.05,1714288.83,1159244.74,2028650.08,1385306.65,1541009.99,1774361.47,1062151.67,1519085.65,1394894.8,1968279.94,1462312.7,1705004.3,1521292.43,1650798.91,1542757.4,1662990.15,1550584.29,1832861.73,1880222.21,1501178.25,1713681.43,1842374.72,1598151.85,1840768.53,2079835.7,1555224.26,1508986.72,968142.49,1635986.0,11471.93,1933805.27,1361085.36,1453291.13,1869334.56,1632321.79,476841.92000000004,1484274.67,99048.58,875792.05,1119119.53,1699787.06,230950.55,1611127.3800000001,1154362.74,1386917.07,1298829.27,1427556.9,1381409.36,1932193.42,1392405.85,1690601.22,1672798.47,1639377.74,2283014.33,1432156.97,21601.05,21173.41,1556786.32,2021927.72,1068622.97,1666986.08,2022570.75,751581.38,1979434.78,1561192.96,1315332.23,1888309.88,1424001.92,2012659.28,1127890.84,1155084.47,1620003.5,1785074.11,1619582.25,1174319.66,214406.49],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","c ...

# %% [markdown]
# Which product categories consistently exhibit high sales, indicating a need for increased inventory stocking to maximize revenue?
#
# Paper, Office Furnishings
#
# Are there identifiable periods or seasons when certain product categories experience heightened sales, necessitating adjusted inventory levels to prevent stockouts?
#
# We see that in the month of June : Binders and Binder accessories have a big spike
#
# Which stores have the highest sales for a particular product category?
#
# First position is taken by Office Machine because of its high pricing in all stores. Second and third positions gets shuffled in between telephones & communication and tables
#
# Are there any seasonal trends in sales at the store level?
#
# March tends to be the month with highest sales irrespective of stores
#
# Which departments generate the most sales revenue for Walmart?
#
# Dept 72
#
# Which states or regions have the highest sales for a particular product category?
#
# Office Machine stands as the most revenue generating in every state. the second position keeps varying .For examples , texas has telephones as second while new jersey has tables.

# %%
# changing values to generate answers for above questions
store_counts = yearly_data.groupby(['month','product_sub_category']).agg({'sales':'sum'}).reset_index()
store_counts.columns = ['month','product_sub_category','sales']
fig = px.bar(store_counts, x="month", y="sales", color="product_sub_category", title="Month-Sub Category counts")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d30b3b7c-b433-455c-b7b2-4ee30e1377c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d30b3b7c-b433-455c-b7b2-4ee30e1377c2")) {                    Plotly.newPlot(                        "d30b3b7c-b433-455c-b7b2-4ee30e1377c2",                        [{"alignmentgroup":"True","hovertemplate":"product_sub_category=Appliances\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[274922.22000000003,433542.51,177203.51,384308.07,306740.65,316545.84,243726.19,416179.6,370265.83,134293.31,233306.8,350238.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Binders and Binder Accessories\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders and Binder Accessories","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Binders and Binder Accessories","offsetgroup":"Binders and Binder Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[505722.71,357749.75,242820.87,320387.47,364299.36,348261.55,811473.9,552416.84,482519.94,146790.67,689015.22,434999.67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Bookcases\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[372766.75,274832.04,213418.91,213985.56,309475.4,233530.18,301480.93,307027.20999999996,239616.39,93901.44,291438.86,345159.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Chairs & Chairmats\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chairs & Chairmats","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chairs & Chairmats","offsetgroup":"Chairs & Chairmats","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[541120.95,530328.51,276723.91,453528.45,502645.75,538613.22,461767.29,691155.1,501499.51,276869.68,528190.35,488524.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Computer Peripherals\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Computer Peripherals","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Computer Peripherals","offsetgroup":"Computer Peripherals","orientation":"v","showlegend":true,"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[221106.88,263993.18,168214.87,227328.62,246264.17,187784.55000000002,267821.03,221595.11,316720.07,81091.98,245453.71,271181.44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Copiers and Fax\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003ce ...

# %%
region_category_sales = inventory_data.groupby(['region', 'product_sub_category']).agg({'sales': 'sum'}).reset_index()
top_regions = region_category_sales.groupby('region')['sales'].sum().nlargest(5).index
top_categories = region_category_sales.groupby('product_sub_category')['sales'].sum().nlargest(10).index

filtered_data = region_category_sales[region_category_sales['region'].isin(top_regions) & region_category_sales['product_sub_category'].isin(top_categories)]

fig = px.bar(filtered_data, x="region", y="sales", color="product_sub_category", title="Regional Sales by Product Categories", barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6573c190-ed4a-4599-917e-086d25bed3d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6573c190-ed4a-4599-917e-086d25bed3d6")) {                    Plotly.newPlot(                        "6573c190-ed4a-4599-917e-086d25bed3d6",                        [{"alignmentgroup":"True","hovertemplate":"product_sub_category=Appliances\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Appliances","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Appliances","offsetgroup":"Appliances","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[1540534.51,1694528.99,1174724.8,1068735.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Binders and Binder Accessories\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Binders and Binder Accessories","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Binders and Binder Accessories","offsetgroup":"Binders and Binder Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[2356447.83,2786048.28,1406506.44,1526246.31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Bookcases\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bookcases","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[1268959.58,1559678.66,1007437.42,1230943.31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Chairs & Chairmats\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chairs & Chairmats","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chairs & Chairmats","offsetgroup":"Chairs & Chairmats","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[2693895.39,2756019.18,1712266.19,1855092.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Copiers and Fax\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Copiers and Fax","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Copiers and Fax","offsetgroup":"Copiers and Fax","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[2961673.66,2722536.6,1238706.43,2182623.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Office Furnishings\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Furnishings","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Office Furnishings","offsetgroup":"Office Furnishings","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[1445194.4,1596296.02,908637.47,1002965.79],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"product_sub_category=Office Machines\u003cbr\u003eregion=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Machines","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Office Machines","offsetgroup":"Office Machines","orientation":"v","showlegend":true,"textposition":"auto","x":["Central","East","South","West"],"xaxis":"x","y":[9965685.38,89 ...

# %%
seasonal_sales = inventory_data.groupby(['month', 'product_sub_category']).agg({'sales': 'sum'}).reset_index()
top_categories = seasonal_sales.groupby('product_sub_category')['sales'].sum().nlargest(5).index

filtered_data = seasonal_sales[seasonal_sales['product_sub_category'].isin(top_categories)]

fig = px.line(filtered_data, x="month", y="sales", color="product_sub_category", title="Seasonal Sales Trends for Top Categories")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aff4a8ed-83a4-4e57-89db-5babee6aac8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aff4a8ed-83a4-4e57-89db-5babee6aac8a")) {                    Plotly.newPlot(                        "aff4a8ed-83a4-4e57-89db-5babee6aac8a",                        [{"hovertemplate":"product_sub_category=Chairs & Chairmats\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chairs & Chairmats","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chairs & Chairmats","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[930913.0,770758.78,582078.09,692386.37,502645.75,897043.59,732547.21,1046726.49,726163.69,534435.58,889081.63,712492.91],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_sub_category=Copiers and Fax\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Copiers and Fax","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Copiers and Fax","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[805968.29,805418.3,630374.87,668253.43,505227.05,855153.9299999999,1062697.12,898098.52,689627.84,508487.69,819959.14,856273.68],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_sub_category=Office Machines\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Office Machines","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Office Machines","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[3708754.21,2463446.36,1721547.99,2813683.4699999997,1896046.81,2353008.89,2582761.58,3435875.9899999998,2674007.41,1458651.85,2314906.38,3062573.17],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_sub_category=Tables\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tables","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Tables","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[1134326.36,968318.38,924115.18,1272383.1300000001,671972.03,1318025.18,1279887.29,1153810.89,804067.22,792720.78,982278.23,950919.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_sub_category=Telephones and Communication\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Telephones and Communication","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Telephones and Communication","orientation":"v","showlegend":true,"x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[1302196.84,1112064.99,889251.89,1050205.69,687880.39,1036882.71,1082478.19,1130805.12,1099652.43,696767.11,1077181.65,1146323.16],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...
